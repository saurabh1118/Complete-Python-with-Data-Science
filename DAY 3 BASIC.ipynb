# %% [markdown]
# # DATA TYPES

# %%
# number

# %%
# integer : data types : -infinite to + infinite

# %%
age = 56
print(56)
# Out:
# 56

# %%
print(id(age))
print(type(age))
# Out:
# 140711433285784
# <class 'int'>

# %%
# Floating : float : decimal values : -ve infinite to +ve infinite

# %%
temp = 45.5
print(temp)
print(type(temp))
print(id(temp))
# Out:
# 45.5
# <class 'float'>
# 1294242375472

# %%
id(temp)
# Out:
# 1294266247632

# %%
# Complex : real + imaginary number which exists in number system
# Imagenary number : i,j,k

# %%
a = 45 + 5j

print(a)
# Out:
# (45+5j)

# %%
# number datatypes : int , float , complex

# %%
# Collection data types : used to store two or more

# %%
name = 'my name is mohan'

print(name)
# Out:
# my name is mohan

# %%
# str

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
# tuple : immatuable
name1 = ('harry',25,25.6,47 + 5j ,(2,25,25),(1,2,3,(24,25,26)))

print(name1)
# Out:
# ('harry', 25, 25.6, (47+5j), (2, 25, 25), (1, 2, 3, (24, 25, 26)))

# %%
print(type(name1))
# Out:
# <class 'tuple'>

# %%
# list : mutualable
data = ['harry',25,25.6,(47 + 5j ),[2,25,25],(1,2,3,[24,25,26])]
print(data)
print(type(data))
# Out:
# ['harry', 25, 25.6, (47+5j), [2, 25, 25], (1, 2, 3, [24, 25, 26])]
# <class 'list'>

# %%
# good word

# good : definition
# key : pair

# %%
# dictionary :==> #mappping, dict,json,hash,key_value_pair data type

# %%
data2 = {'Roll No':23,'Name':'saurabh','class':12}
print(data2)
print(type(data2))
# Out:
# {'Roll No': 23, 'Name': 'saurabh', 'class': 12}
# <class 'dict'>

# %%
data2['name'] = 'Saurabh Kumar'

# %%
print(data2)
# Out:
# {'Roll No': 23, 'Name': 'saurabh', 'class': 12, 'name': 'Saurabh Kumar'}

# %%
data2['class'] = 'College'

# %%
print(data2)
# Out:
# {'Roll No': 23, 'Name': 'saurabh', 'class': 'College', 'name': 'Saurabh Kumar'}

# %%
data = {'name':['arav','biru','guru'],
        'age':[12,25,36],
        'address':['agra','mtr','delhi']
       }

# %%
print(data)
# Out:
# {'name': ['arav', 'biru', 'guru'], 'age': [12, 25, 36], 'address': ['agra', 'mtr', 'delhi']}

# %%
import pandas as pd

# %%
table = pd.DataFrame(data)

# %%
print(table)
# Out:
#    name  age address
# 0  arav   12    agra
# 1  biru   25     mtr
# 2  guru   36   delhi

# %%
 table.to_excel('Student.xlsx')
print('Done!!')
# Out:
# Done!!

# %%
#Modules

# %%
# 6.5 modules in python

# %%
# 25-30 modules are necessorry to know about them

# %%
import cowsay

print('Done')
# Out:
# Done

# %%
 # pip install cowsay
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
cowsay.cow('Hello Brijlal Ji')
# Out:
#   ________________
# | Hello Brijlal Ji |
# ...
#                 \
#                  \
#                    ^__^
#                    (oo)\_______
#                    (__)\       )\/\
#                        ||----w |
#                        ||     ||

# %%
cowsay.trex('hello')
# Out:
#   _____
# | hello |
#   =====
#             \
#              \
#               \
#                \
#                   .-=-==--==--.
#             ..-=="  ,'o`)      `.
#           ,'         `"'         \
#          :  (                     `.__...._
#          |                  )    /         `-=-.
#          :       ,vv.-._   /    /               `---==-._
#           \/\/\/VV ^ d88`;'    /                         `.
#               ``  ^/d88P!'    /             ,              `._
#                  ^/    !'   ,.      ,      /                  "-,,__,,--'""""-.
#                 ^/    !'  ,'  \ . .(      (         _           )  ) ) ) ))_,-.\
#                ^(__ ,!',"'   ;:+.:%:a.     \:.. . ,'          )  )  ) ) ,"'    '
#                ',,,'','     /o:::":%:%a.    \:.:.:         .    )  ) _,'
#                 """'       ;':::'' `+%%%a._  \%:%|         ;.). _,-""
#                        ,-='_.-'      ``:%::)  )%:|        /:._,"
# ...

# %%
data = ['mohan','komal','mohan','komal','mohan','arav']

# %%
print(data)
# Out:
# ['mohan', 'komal', 'mohan', 'komal', 'mohan']

# %%
# set : unique data , unordered data

# %%
data1 = {'mohan','komal','mohan','komal','mohan','arav'}
print(data1)
# Out:
# {'komal', 'arav', 'mohan'}

# %%
data101 = ['mohan','komal','mohan','komal','mohan','arav','say','adda']
print(data101)
# Out:
# ['mohan', 'komal', 'mohan', 'komal', 'mohan', 'arav', 'say', 'adda']

# %%
set(data101)
# Out:
# {'adda', 'arav', 'komal', 'mohan', 'say'}

# %%
# boolean : True , False

# %%
data = {false,1,2,3,0,true,1,0,2}

print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 data={false,1,2,3,0,true,1,0,2}
#       3 print(data)
#
# NameError: name 'false' is not defined

# %%
a =
print(a)
# Out:
#   Cell In[60], line 1
#     a =
#        ^
# SyntaxError: invalid syntax

# %%
a = None
print(a)
# Out:
# None

# %%
print(type(a))
# Out:
# <class 'NoneType'>

# %% [markdown]
# # ![image.png](attachment:236a4fe4-b9d2-4340-a026-b2ab4fd90504.png)

# %%
data = frozenset({45,251,25564})
print(data)
# Out:
# frozenset({251, 25564, 45})

# %%
print(type(data))
# Out:
# <class 'frozenset'>

# %%
data.add(455)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 data.add(455)
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
# A,B,C,D
# Words
# Sentences
# paragraphs
# Stories
# Books
# # Libraries
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 A,B,C,D
#
# NameError: name 'A' is not defined

# %%
help('keywords')
# Out:
# Here is a list of the Python keywords.  Enter any keyword to get more help.
#
# False               class               from                or
# None                continue            global              pass
# True                def                 if                  raise
# and                 del                 import              return
# as                  elif                in                  try
# assert              else                is                  while
# async               except              lambda              with
# await               finally             nonlocal            yield
# break               for                 not

# %%
# Data Types => Conditional Programming => Functional Programming => OOPS
# Modules =>libraries => Packages =>Software
