# %%
# Shortcuts

# %% [markdown]
# # Python Introduction

# %% [markdown]
# ![image.png](attachment:94fffd53-5397-4780-a470-5bbd6c9fa1a0.png)

# %% [markdown]
# - Python is a high-level, interpreted, general-purpose programming language known for its readability and ease of use.
#
#   It was created by `Guido van Rossum` and first released in 1991.
#
# - Key characteristics of Python include:
# - **`High-level`**:
# Python abstracts away low-level details like memory management, allowing developers to focus on problem-solving.
#
# - **`Interpreted`**:
# Python code is executed line by line by an interpreter, rather than being compiled into machine code beforehand. This enables rapid development and testing.
# - **`Object-oriented`**:
# Python supports object-oriented programming (OOP) paradigms, allowing for structured and modular code organization through objects and classes.

# %% [markdown]
# # Title 1
# ## Title 1
# ### Title 1
# #### Title 1
# ##### Title 1
# ###### Title 1
# ########## Title 1

# %%
print('click left side and press A')

print(1253)

print('4545')

print('hello orry')

print('suraj')

print('Meteor 650')
# Out:
# click left side and press A
# 1253
# 4545
# hello orry
# suraj
# Meteor 650

# %%
#data containers : Data types

# %%
age = 34

# %%
print(age)
# Out:
# 34

# %%
# memory management in Python

# %%
a = 58

# %%
b = 58

# %%
print(a)
id(a)
# Out:
# 58
# 140711241461976

# %%
print(b)
id(b)
# Out:
# 58
# 140711241461976

# %%
c = 256
d = 256

# %%
print(c)
id(c)
# Out:
# 256
# 140711241468312

# %%
print(d)
id(d)
# Out:
# 256
# 140711241468312

# %%
# a=58 & b=58 then ID address(pointer) of a & b are same ,
# c=256 & d=256 then ID address(pointer) of c & d are same ,
# bcoz python itself doing memory management 
# a =58 have id address then b pointer memory address of a , bcoz a = b 
# when assigning value >= 256 then python didnot use extra memory space

# %%
x=257

print(x)
id(x)
# Out:
# 257
# 1892359576400

# %%
y=257
print(y)
id(y)
# Out:
# 257
# 1892359581456

# %%
# when assigning values <256 then ID address is differnt for all assined containers
# if assigning values >=256 then id address is same for all assigned containers

# %%
h = 25.0
i = 25.0
j = 25.00
l = 25.0000

# %%
id(h),id(j),id(i),id(l)
# Out:
# (1892336298352, 1892359583696, 1892359582096, 1892359583280)

# %%
name = 'dhrub'
name2 = 'dhrub'

id(name),id(name2)
# Out:
# (1892360987552, 1892360987552)

# %%
# Dynamic Symmetrics

# %%
# In Python , there is  no need to declare datatypes as any other programming language,
# It declare datatypes by itselfs according to its data

# %%
int z = 25
print(z)
# Out:
#   Cell In[52], line 1
#     int z = 25
#         ^
# SyntaxError: invalid syntax

# %%
z = 25
print(z)
type(z)
# Out:
# 25
# int

# %%
u = 'komal'
print(u)
type(u)
# Out:
# komal
# str

# %%
# Interpreter : It runs the code lin by line

# %%
print('hello world')
print('hello world')
print('hello world')
print(q)
print('hello world')
print('hello world')
# Out:
# hello world
# hello world
# hello world
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[58], line 4
#       2 print('hello world')
#       3 print('hello world')
# ----> 4 print(q)
#       5 print('hello world')
#       6 print('hello world')
#
# NameError: name 'q' is not defined

# %%
# Number
# int , float , complex

# %%
t =25
print(t,type(t))
# Out:
# 25 <class 'int'>

# %%
w= 25.25
print(w,type(w))
# Out:
# 25.25 <class 'float'>

# %%
s = 65 + 3j
print(s,type(s))
# Out:
# (65+3j) <class 'complex'>

# %%
# Textual Data
# String : str

# %%
r = 'My name is Saurabh'
print(r,type(r))
# Out:
# My name is Saurabh <class 'str'>

# %%
# Collections : Tuple , List

# %%
 t=(45,45.36,'mohan',45+6j)

print(t,type(t))
# Out:
# (45, 45.36, 'mohan', (45+6j)) <class 'tuple'>

# %%
l=[45,45.36,'mohan',45+6j]

print(l,type(l))
# Out:
# [45, 45.36, 'mohan', (45+6j)] <class 'list'>
